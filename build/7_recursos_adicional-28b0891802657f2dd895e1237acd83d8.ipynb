# %% [markdown]
# # Recursos Adicionales

# %% [markdown]
# | 📥 Recurso | 🔗 Enlace | 📝 Descripción |
# |---|---|---|
# | **Reporte PDF** | [Descargar](media/reporte.pdf) | Documento con el análisis completo, métricas del modelo y conclusiones del proyecto. |
# | **Demo en vivo** | [Abrir](https://huggingface.co/spaces/acamacho0723/pseudocentrosaludnayarit) | Interfaz web interactiva para probar el modelo predictivo en tiempo real. |
